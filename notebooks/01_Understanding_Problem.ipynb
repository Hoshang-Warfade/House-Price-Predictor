# %% [markdown]
# # Understanding Problem

# %% [markdown]
# ## Objective
#
# Understand the machine learning problem before exploring the dataset.

# %% [markdown]
# ## Questions

# %% [markdown]
# **#1: what is target varible?**<br>
# -->In this problem we predicting house price based on property of house ,so target varible house price.

# %% [markdown]
# **#2: what ml problem is this ?** <br>
# -->This is Regression problem becoz target varible can take any continuous numeric value

# %% [markdown]
# **#3: What are possible features?**<br>
# - Number of bedrooms
# - Number of bathrooms
# - House area
# - Number of floors
# - Furnished or not
# - Age of the house
# - Parking spaces
# - Neighborhood
